# %% [markdown]
# <a href="https://colab.research.google.com/github/vanhungtran/machine-learning/blob/master/Machine_learning__Diabete2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
fname = 'https://raw.githubusercontent.com/vanhungtran/opendata/refs/heads/main/diabetes2.csv'
patients= pd.read_csv(fname, low_memory=False)
patients.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df= pd.DataFrame(patients)
df.head(1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.drop("Age", axis = 1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Outcome
# 0                       0.627        1
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.boxplot(figsize=(20, 6))
# Out:
# <Axes: >

# %%
df.plot.box(vert=False)
# Out:
# <Axes: >

# %%
df.plot.box(vert=True, figsize=(20, 6))
# Out:
# <Axes: >

# %%
df.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %%
df.hist(figsize=(20,6))
# Out:
# array([[<Axes: title={'center': 'Pregnancies'}>,
#         <Axes: title={'center': 'Glucose'}>,
#         <Axes: title={'center': 'BloodPressure'}>],
#        [<Axes: title={'center': 'SkinThickness'}>,
#         <Axes: title={'center': 'Insulin'}>,
#         <Axes: title={'center': 'BMI'}>],
#        [<Axes: title={'center': 'DiabetesPedigreeFunction'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Outcome'}>]], dtype=object)

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
df.plot.scatter(x="Age",y="Glucose")
# Out:
# <Axes: xlabel='Age', ylabel='Glucose'>

# %%
my_tab = pd.crosstab(index=df["Age"], columns="Count")
my_tab
# Out:
# col_0  Count
# Age
# 21        63
# 22        72
# 23        38
# 24        46
# 25        48
# 26        33
# 27        32
# 28        35
# 29        29
# 30        21
# 31        24
# 32        16
# 33        17
# 34        14
# 35        10
# 36        16
# 37        19
# 38        16
# 39        12
# 40        13
# 41        22
# 42        18
# 43        13
# 44         8
# 45        15
# 46        13
# 47         6
# 48         5
# 49         5
# 50         8
# 51         8
# 52         8
# 53         5
# 54         6
# 55         4
# 56         3
# 57         5
# 58         7
# 59         3
# 60         5
# 61         2
# 62         4
# 63         4
# 64         1
# 65         3
# 66         4
# 67         3
# 68         1
# 69         2
# 70         1
# 72         1
# 81         1

# %%
my_tab=df.sort_values('Age', ascending=[False])
print(my_tab)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 459            9      134             74             33       60  25.9
# 453            2      119              0              0        0  19.6
# 666            4      145             82             18        0  32.5
# 684            5      136             82              0        0   0.0
# 123            5      132             80              0        0  26.8
# ..           ...      ...            ...            ...      ...   ...
# 736            0      126             86             27      120  27.4
# 273            1       71             78             50       45  33.2
# 713            0      134             58             20      291  26.4
# 290            0       78             88             29       40  36.9
# 3              1       89             66             23       94  28.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 459                     0.460   81        0
# ...

# %%
data_counts = pd.DataFrame(my_tab)
pd.DataFrame(data_counts).plot(kind='bar', stacked=False)
# Out:
# <Axes: >

# %%
data_counts
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 459            9      134             74             33       60  25.9
# 453            2      119              0              0        0  19.6
# 666            4      145             82             18        0  32.5
# 684            5      136             82              0        0   0.0
# 123            5      132             80              0        0  26.8
# ..           ...      ...            ...            ...      ...   ...
# 736            0      126             86             27      120  27.4
# 273            1       71             78             50       45  33.2
# 713            0      134             58             20      291  26.4
# 290            0       78             88             29       40  36.9
# 3              1       89             66             23       94  28.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 459                     0.460   81        0
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetics = pd.DataFrame(df['Outcome'])
features = pd.DataFrame(df.drop('Outcome', axis = 1))
diabetics.columns
features.columns
features_raw = features.copy()

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# Import sklearn.preprocessing.StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
# Initialize a scaler, then apply it to the features
scaler = MinMaxScaler()
numerical = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness','Insulin',"BMI","DiabetesPedigreeFunction","Age"]
features_raw[numerical] = scaler.fit_transform(df[numerical])

# %%
display(features_raw.head(10))
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
# 5     0.294118  0.582915       0.606557       0.000000  0.000000  0.381520
# 6     0.176471  0.391960       0.409836       0.323232  0.104019  0.461997
# 7     0.588235  0.577889       0.000000       0.000000  0.000000  0.526080
# 8     0.117647  0.989950       0.573770       0.454545  0.641844  0.454545
# 9     0.470588  0.628141       0.786885       0.000000  0.000000  0.000000
#
#    DiabetesPedigreeFunction       Age
# 0                  0.234415  0.483333
# 1                  0.116567  0.166667
# ...

# %%
# Step 3 One-hot encode the 'features_raw' data using pandas.get_dummies()
features = pd.get_dummies(features_raw)

# %%
features
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1       0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2       0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3       0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4       0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
# ..           ...       ...            ...            ...       ...       ...
# 763     0.588235  0.507538       0.622951       0.484848  0.212766  0.490313
# 764     0.117647  0.613065       0.573770       0.272727  0.000000  0.548435
# 765     0.294118  0.608040       0.590164       0.232323  0.132388  0.390462
# 766     0.058824  0.633166       0.491803       0.000000  0.000000  0.448584
# 767     0.058824  0.467337       0.573770       0.313131  0.000000  0.453055
#
#      DiabetesPedigreeFunction       Age
# ...

# %%
display(features.head(1),diabetics.head(1))
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness  Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535      0.0  0.500745
#
#    DiabetesPedigreeFunction       Age
# 0                  0.234415  0.483333
#    Outcome
# 0        1

# %%
diabetics.head(1)
# Out:
#    Outcome
# 0        1

# %%
# Print the number of features after one-hot encoding
encoded = list(features.columns)
print("{} total features after one-hot encoding.".format(len(encoded)))
# Out:
# 8 total features after one-hot encoding.

# %%
print(encoded)
display(features.head(1),diabetics.head(1))
# Out:
# ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
#    Pregnancies   Glucose  BloodPressure  SkinThickness  Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535      0.0  0.500745
#
#    DiabetesPedigreeFunction       Age
# 0                  0.234415  0.483333
#    Outcome
# 0        1

# %%
print("{} encoding.".format(len(encoded)))
# Out:
# 8 encoding.

# %%
#Step 4 Shuffle & Split Final Dataset
# Import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
# Shuffle and split the data into training and testing subsets
features=shuffle(features, random_state=0)

# %%
diabetics=shuffle(diabetics, random_state=0)
# Split the 'features' and 'income' data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, diabetics,test_size = 0.2, random_state = 0)
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# Training set has 614 samples.
# Testing set has 154 samples.

# %%
#Loading model Libraries
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
# prepare models
#Using seed to maintain reproducability and consistent results
seed = 7
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
models.append(('RFC', RandomForestClassifier()))

# %%
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
import warnings
warnings.filterwarnings("ignore")
for name, model in models:
    kfold = model_selection.KFold(n_splits=10, random_state=seed, shuffle=True)
    cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.778477 (0.048458)
# LDA: 0.776864 (0.054096)
# KNN: 0.731280 (0.063586)
# CART: 0.693813 (0.055127)
# NB: 0.762189 (0.062319)
# SVM: 0.771946 (0.054775)
# RFC: 0.786542 (0.047420)

# %%
results
# Out:
# [array([0.82258065, 0.70967742, 0.75806452, 0.83870968, 0.81967213,
#         0.85245902, 0.73770492, 0.7704918 , 0.75409836, 0.72131148]),
#  array([0.80645161, 0.69354839, 0.79032258, 0.82258065, 0.83606557,
#         0.85245902, 0.73770492, 0.78688525, 0.75409836, 0.68852459]),
#  array([0.72580645, 0.66129032, 0.82258065, 0.70967742, 0.68852459,
#         0.85245902, 0.67213115, 0.72131148, 0.78688525, 0.67213115]),
#  array([0.69354839, 0.69354839, 0.66129032, 0.72580645, 0.7704918 ,
#         0.78688525, 0.59016393, 0.70491803, 0.6557377 , 0.6557377 ]),
#  array([0.83870968, 0.67741935, 0.72580645, 0.82258065, 0.78688525,
#         0.85245902, 0.7704918 , 0.73770492, 0.75409836, 0.6557377 ]),
#  array([0.82258065, 0.70967742, 0.80645161, 0.77419355, 0.7704918 ,
#         0.8852459 , 0.72131148, 0.7704918 , 0.7704918 , 0.68852459]),
#  array([0.80645161, 0.74193548, 0.82258065, 0.83870968, 0.80327869,
#         0.86885246, 0.73770492, 0.73770492, 0.78688525, 0.72131148])]

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Train each model on the full training data and predict probabilities on the test set
plt.figure(figsize=(10, 8))
for name, model in models:
    model.fit(X_train, y_train)
    if hasattr(model, "predict_proba"):
        y_pred_proba = model.predict_proba(X_test)[:, 1]
    else:
        # Some models like SVM with linear kernel don't have predict_proba
        # In that case, we can use decision_function if available
        if hasattr(model, "decision_function"):
            y_pred_proba = model.decision_function(X_test)
        else:
            # Fallback for models without probability or decision function
            print(f"Model {name} does not have predict_proba or decision_function.")
            continue

    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'{name} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Different Models')
plt.legend()
plt.grid(True)
plt.show()
